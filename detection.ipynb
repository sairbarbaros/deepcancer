# %% [markdown]
# 1. IMPORTING ESSENTIAL LIBRARIES FOR THIS PROJECT

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from random import shuffle
import numpy as np

# %% [markdown]
# 2. LOADING TRAINING AND TEST DATASETS FROM BRAIN_TUMOR_DATASET DIRECTORY

# %%
path = "brain_tumor_dataset/"
training_set = tf.keras.preprocessing.image_dataset_from_directory(path,
                                             shuffle=True,
                                             batch_size=32,
                                             image_size=(160,160),
                                             validation_split=0.1,
                                             subset='training',
                                             seed=34)
test_set = tf.keras.preprocessing.image_dataset_from_directory(path,
                                             shuffle=True,
                                             batch_size=32,
                                             image_size=(160,160),
                                             validation_split=0.16,
                                             subset='validation',
                                             seed=34)
# Out:
# Found 253 files belonging to 2 classes.
# Using 228 files for training.
# Found 253 files belonging to 2 classes.
# Using 40 files for validation.

# %%
class_names = training_set.class_names

plt.figure(figsize=(10, 10))
for images, labels in training_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# 3. DEFINING DATA AUGMENTATION AND MODEL FUNCTIONS

# %%
def data_augmenter():
    """ augment your data for making your data less prone to overfitting.
    :returns: data augmentation model
    """

    data_augmentation = tf.keras.Sequential()
    data_augmentation.add(tf.keras.layers.experimental.preprocessing.RandomFlip("vertical"))
    data_augmentation.add(tf.keras.layers.experimental.preprocessing.RandomRotation(0.34))
    data_augmentation.add(tf.keras.layers.experimental.preprocessing.RandomCrop(160,160))
    data_augmentation.add(tf.keras.layers.experimental.preprocessing.RandomContrast(0.7, 1.2))
    
    return data_augmentation

# %%
def tumor_identifier(image_shape=(160,160), data_augmentation=data_augmenter()):
    """ create a model for your tumor identification project. you can also use other applications of keras.
    :param image_shape: shape of the input images
    :type image_shape: tuple
    :param data
    """

    input_shape = image_shape + (3,)

    base_model = tf.keras.applications.MobileNetV3Small(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = False

    inputs = tf.keras.Input(shape=input_shape) 
    
    x = data_augmentation(inputs) 
    x = tf.keras.applications.mobilenet_v3.preprocess_input(x)
    
    x = base_model(x, training=False) 
    
    x = tf.keras.layers.GlobalMaxPooling2D()(x) 
    x = tf.keras.layers.Dropout(0.34)(x)
        
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    model = tf.keras.Model(inputs, outputs)
    

    return model

# %% [markdown]
# 4. COMPILING AND SETTING METRICS

# %%
brain_model = tumor_identifier((160,160), data_augmenter())

brain_model.summary()

brain_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 160, 160, 3)       0
# _________________________________________________________________
# MobilenetV3small (Functional (None, 1, 1, 1024)        1529968
# _________________________________________________________________
# global_max_pooling2d_2 (Glob (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 1,530,993
# Trainable params: 1,025
# Non-trainable params: 1,529,968
# _________________________________________________________________

# %% [markdown]
# 5. TRAINING AND GETTING RESULTS

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,)
history = brain_model.fit(
        training_set,
        validation_data=test_set,
        epochs=300, 
        shuffle=True, 
        verbose=True,
        callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 8/8 [==============================] - 4s 176ms/step - loss: 0.7956 - accuracy: 0.5044 - val_loss: 0.7103 - val_accuracy: 0.4750
# Epoch 2/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6924 - accuracy: 0.5921 - val_loss: 0.6491 - val_accuracy: 0.6000
# Epoch 3/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5880 - accuracy: 0.6579 - val_loss: 0.5930 - val_accuracy: 0.6750
# Epoch 4/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5849 - accuracy: 0.7061 - val_loss: 0.5686 - val_accuracy: 0.7000
# Epoch 5/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5132 - accuracy: 0.7588 - val_loss: 0.5429 - val_accuracy: 0.7000
# Epoch 6/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5014 - accuracy: 0.7325 - val_loss: 0.5174 - val_accuracy: 0.7750
# Epoch 7/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4485 - accuracy: 0.8246 - val_loss: 0.5125 - val_accuracy: 0.7500
# Epoch 8/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4376 - accuracy: 0.8158 - val_loss: 0.4966 - val_accuracy: 0.7500
# Epoch 9/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4420 - accuracy: 0.8114 - val_loss: 0.4826 - val_accuracy: 0.7750
# Epoch 10/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4141 - accuracy: 0.8289 - val_loss: 0.4612 - val_accuracy: 0.8250
# Epoch 11/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3764 - accuracy: 0.8289 - val_loss: 0.4410 - val_accuracy: 0.8000
# Epoch 12/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3886 - accuracy: 0.8246 - val_loss: 0.4288 - val_accuracy: 0.8000
# Epoch 13/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3631 - accuracy: 0.8333 - val_loss: 0.4190 - val_accuracy: 0.8000
# Epoch 14/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4016 - accuracy: 0.8026 - val_loss: 0.4134 - val_accuracy: 0.8000
# Epoch 15/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3820 - accuracy: 0.8333 - val_loss: 0.4063 - val_accuracy: 0.7750
# Epoch 16/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3523 - accuracy: 0.8553 - val_loss: 0.3991 - val_accuracy: 0.8000
# Epoch 17/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3512 - accuracy: 0.8509 - val_loss: 0.3954 - val_accuracy: 0.8250
# Epoch 18/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3800 - accuracy: 0.8465 - val_loss: 0.3948 - val_accuracy: 0.8250
# Epoch 19/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3340 - accuracy: 0.8465 - val_loss: 0.3986 - val_accuracy: 0.8500
# Epoch 20/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3594 - accuracy: 0.8377 - val_loss: 0.4065 - val_accuracy: 0.8500
# Epoch 21/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3096 - accuracy: 0.8553 - val_loss: 0.3886 - val_accuracy: 0.8500
# Epoch 22/300
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3450 - accuracy: 0.8596 - val_loss: 0.3887 - val_accuracy: 0.8500
# Epoch 23/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3011 - accuracy: 0.8596 - val_loss: 0.3769 - val_accuracy: 0.8500
# Epoch 24/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3500 - accuracy: 0.8509 - val_loss: 0.3741 - val_accuracy: 0.8500
# Epoch 25/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3165 - accuracy: 0.8684 - val_loss: 0.3698 - val_accuracy: 0.8500
# Epoch 26/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2893 - accuracy: 0.8860 - val_loss: 0.3610 - val_accuracy: 0.8250
# Epoch 27/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3014 - accuracy: 0.8772 - val_loss: 0.3611 - val_accuracy: 0.8250
# Epoch 28/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2846 - accuracy: 0.8947 - val_loss: 0.3673 - val_accuracy: 0.8500
# Epoch 29/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3218 - accuracy: 0.8377 - val_loss: 0.3761 - val_accuracy: 0.8500
# Epoch 30/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3613 - accuracy: 0.8377 - val_loss: 0.3667 - val_accuracy: 0.8500
# Epoch 31/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2967 - accuracy: 0.9079 - val_loss: 0.3661 - val_accuracy: 0.8500
# Epoch 32/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2847 - accuracy: 0.8684 - val_loss: 0.3657 - val_accuracy: 0.8250
# Epoch 33/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2910 - accuracy: 0.8816 - val_loss: 0.3636 - val_accuracy: 0.8250
# Epoch 34/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3261 - accuracy: 0.8684 - val_loss: 0.3624 - val_accuracy: 0.8500
# Epoch 35/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2943 - accuracy: 0.8816 - val_loss: 0.3632 - val_accuracy: 0.8500
# Epoch 36/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2906 - accuracy: 0.8816 - val_loss: 0.3571 - val_accuracy: 0.8250
# Epoch 37/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3401 - accuracy: 0.8553 - val_loss: 0.3534 - val_accuracy: 0.7500
# Epoch 38/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2987 - accuracy: 0.8684 - val_loss: 0.3502 - val_accuracy: 0.8000
# Epoch 39/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2855 - accuracy: 0.8860 - val_loss: 0.3496 - val_accuracy: 0.8000
# Epoch 40/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2818 - accuracy: 0.8904 - val_loss: 0.3490 - val_accuracy: 0.8500
# Epoch 41/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2924 - accuracy: 0.8640 - val_loss: 0.3468 - val_accuracy: 0.8500
# Epoch 42/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3169 - accuracy: 0.8728 - val_loss: 0.3424 - val_accuracy: 0.8500
# Epoch 43/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2665 - accuracy: 0.8728 - val_loss: 0.3376 - val_accuracy: 0.8250
# Epoch 44/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2451 - accuracy: 0.9123 - val_loss: 0.3455 - val_accuracy: 0.8750
# Epoch 45/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2402 - accuracy: 0.9167 - val_loss: 0.3409 - val_accuracy: 0.8250
# Epoch 46/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2887 - accuracy: 0.8684 - val_loss: 0.3351 - val_accuracy: 0.8000
# Epoch 47/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2722 - accuracy: 0.8947 - val_loss: 0.3360 - val_accuracy: 0.8000
# Epoch 48/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2690 - accuracy: 0.8947 - val_loss: 0.3382 - val_accuracy: 0.8250
# Epoch 49/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2339 - accuracy: 0.9079 - val_loss: 0.3364 - val_accuracy: 0.8500
# Epoch 50/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2708 - accuracy: 0.9035 - val_loss: 0.3309 - val_accuracy: 0.8000
# Epoch 51/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2457 - accuracy: 0.9167 - val_loss: 0.3264 - val_accuracy: 0.8000
# Epoch 52/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2719 - accuracy: 0.8860 - val_loss: 0.3280 - val_accuracy: 0.8250
# Epoch 53/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2378 - accuracy: 0.9386 - val_loss: 0.3276 - val_accuracy: 0.8000
# Epoch 54/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2696 - accuracy: 0.8728 - val_loss: 0.3274 - val_accuracy: 0.8000
# Epoch 55/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2496 - accuracy: 0.9035 - val_loss: 0.3356 - val_accuracy: 0.8750
# Epoch 56/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2549 - accuracy: 0.9035 - val_loss: 0.3322 - val_accuracy: 0.8750
# Epoch 57/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2601 - accuracy: 0.8991 - val_loss: 0.3247 - val_accuracy: 0.8500
# Epoch 58/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2556 - accuracy: 0.9167 - val_loss: 0.3136 - val_accuracy: 0.8500
# Epoch 59/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2434 - accuracy: 0.9298 - val_loss: 0.3108 - val_accuracy: 0.8500
# Epoch 60/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2326 - accuracy: 0.8904 - val_loss: 0.3067 - val_accuracy: 0.7750
# Epoch 61/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2497 - accuracy: 0.9167 - val_loss: 0.3064 - val_accuracy: 0.8000
# Epoch 62/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2522 - accuracy: 0.9167 - val_loss: 0.3069 - val_accuracy: 0.8250
# Epoch 63/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2715 - accuracy: 0.8684 - val_loss: 0.3036 - val_accuracy: 0.8000
# Epoch 64/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2354 - accuracy: 0.9254 - val_loss: 0.3132 - val_accuracy: 0.8750
# Epoch 65/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2395 - accuracy: 0.9079 - val_loss: 0.3150 - val_accuracy: 0.8750
# Epoch 66/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2323 - accuracy: 0.9079 - val_loss: 0.3070 - val_accuracy: 0.8750
# Epoch 67/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2352 - accuracy: 0.8947 - val_loss: 0.3121 - val_accuracy: 0.8750
# Epoch 68/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2525 - accuracy: 0.9035 - val_loss: 0.3320 - val_accuracy: 0.8750
# Epoch 69/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2963 - accuracy: 0.8772 - val_loss: 0.3180 - val_accuracy: 0.8750
# Epoch 70/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2634 - accuracy: 0.8772 - val_loss: 0.3041 - val_accuracy: 0.8750
# Epoch 71/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2529 - accuracy: 0.8947 - val_loss: 0.3055 - val_accuracy: 0.8750
# Epoch 72/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2375 - accuracy: 0.9123 - val_loss: 0.2986 - val_accuracy: 0.8750
# Epoch 73/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2238 - accuracy: 0.9254 - val_loss: 0.2893 - val_accuracy: 0.8500
# Epoch 74/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2642 - accuracy: 0.8904 - val_loss: 0.2919 - val_accuracy: 0.8750
# Epoch 75/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2181 - accuracy: 0.9079 - val_loss: 0.2901 - val_accuracy: 0.8750
# Epoch 76/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2236 - accuracy: 0.9123 - val_loss: 0.2835 - val_accuracy: 0.8250
# Epoch 77/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2492 - accuracy: 0.8991 - val_loss: 0.2817 - val_accuracy: 0.8250
# Epoch 78/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2584 - accuracy: 0.9035 - val_loss: 0.2839 - val_accuracy: 0.8250
# Epoch 79/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1995 - accuracy: 0.9123 - val_loss: 0.2891 - val_accuracy: 0.8750
# Epoch 80/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2415 - accuracy: 0.8947 - val_loss: 0.2828 - val_accuracy: 0.8500
# Epoch 81/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2369 - accuracy: 0.9035 - val_loss: 0.2792 - val_accuracy: 0.8500
# Epoch 82/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2478 - accuracy: 0.9167 - val_loss: 0.2784 - val_accuracy: 0.8500
# Epoch 83/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2236 - accuracy: 0.9167 - val_loss: 0.2773 - val_accuracy: 0.8500
# Epoch 84/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2335 - accuracy: 0.8991 - val_loss: 0.2774 - val_accuracy: 0.8750
# Epoch 85/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2467 - accuracy: 0.8904 - val_loss: 0.2770 - val_accuracy: 0.8750
# Epoch 86/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2264 - accuracy: 0.9167 - val_loss: 0.2687 - val_accuracy: 0.8750
# Epoch 87/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2235 - accuracy: 0.9035 - val_loss: 0.2647 - val_accuracy: 0.8750
# Epoch 88/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2566 - accuracy: 0.8904 - val_loss: 0.2612 - val_accuracy: 0.8750
# Epoch 89/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2147 - accuracy: 0.9167 - val_loss: 0.2633 - val_accuracy: 0.8750
# Epoch 90/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2175 - accuracy: 0.9211 - val_loss: 0.2598 - val_accuracy: 0.8750
# Epoch 91/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1981 - accuracy: 0.9254 - val_loss: 0.2588 - val_accuracy: 0.8750
# Epoch 92/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2197 - accuracy: 0.9079 - val_loss: 0.2571 - val_accuracy: 0.8750
# Epoch 93/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2136 - accuracy: 0.9167 - val_loss: 0.2562 - val_accuracy: 0.8500
# Epoch 94/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2825 - accuracy: 0.8947 - val_loss: 0.2578 - val_accuracy: 0.8500
# Epoch 95/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2384 - accuracy: 0.8904 - val_loss: 0.2574 - val_accuracy: 0.8500
# Epoch 96/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2395 - accuracy: 0.9123 - val_loss: 0.2525 - val_accuracy: 0.8500
# Epoch 97/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2387 - accuracy: 0.8947 - val_loss: 0.2591 - val_accuracy: 0.8750
# Epoch 98/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2316 - accuracy: 0.9123 - val_loss: 0.2541 - val_accuracy: 0.8750
# Epoch 99/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2471 - accuracy: 0.8991 - val_loss: 0.2487 - val_accuracy: 0.8750
# Epoch 100/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2472 - accuracy: 0.8860 - val_loss: 0.2480 - val_accuracy: 0.8500
# Epoch 101/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2100 - accuracy: 0.9123 - val_loss: 0.2487 - val_accuracy: 0.8000
# Epoch 102/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1991 - accuracy: 0.9254 - val_loss: 0.2515 - val_accuracy: 0.8000
# Epoch 103/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2339 - accuracy: 0.8904 - val_loss: 0.2476 - val_accuracy: 0.8500
# Epoch 104/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1690 - accuracy: 0.9474 - val_loss: 0.2543 - val_accuracy: 0.8750
# Epoch 105/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2047 - accuracy: 0.9386 - val_loss: 0.2536 - val_accuracy: 0.8750
# Epoch 106/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1998 - accuracy: 0.9254 - val_loss: 0.2445 - val_accuracy: 0.8500
# Epoch 107/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2396 - accuracy: 0.9298 - val_loss: 0.2441 - val_accuracy: 0.8500
# Epoch 108/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2027 - accuracy: 0.9123 - val_loss: 0.2435 - val_accuracy: 0.8500
# Epoch 109/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2401 - accuracy: 0.9079 - val_loss: 0.2453 - val_accuracy: 0.8500
# Epoch 110/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2003 - accuracy: 0.9386 - val_loss: 0.2477 - val_accuracy: 0.8500
# Epoch 111/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1964 - accuracy: 0.9386 - val_loss: 0.2470 - val_accuracy: 0.8500
# Epoch 112/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1943 - accuracy: 0.9123 - val_loss: 0.2458 - val_accuracy: 0.8750
# Epoch 113/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2002 - accuracy: 0.9386 - val_loss: 0.2530 - val_accuracy: 0.8750
# Epoch 114/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1951 - accuracy: 0.9167 - val_loss: 0.2550 - val_accuracy: 0.8750
# Epoch 115/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1857 - accuracy: 0.9167 - val_loss: 0.2562 - val_accuracy: 0.8750
# Epoch 116/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2792 - accuracy: 0.8772 - val_loss: 0.2445 - val_accuracy: 0.8750
# Epoch 117/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1591 - accuracy: 0.9605 - val_loss: 0.2421 - val_accuracy: 0.8750
# Epoch 118/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2225 - accuracy: 0.9211 - val_loss: 0.2420 - val_accuracy: 0.8750
# Epoch 119/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2433 - accuracy: 0.8904 - val_loss: 0.2411 - val_accuracy: 0.8750
# Epoch 120/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1929 - accuracy: 0.9211 - val_loss: 0.2389 - val_accuracy: 0.8500
# Epoch 121/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1942 - accuracy: 0.9079 - val_loss: 0.2429 - val_accuracy: 0.8500
# Epoch 122/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2119 - accuracy: 0.9079 - val_loss: 0.2463 - val_accuracy: 0.8750
# Epoch 123/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1957 - accuracy: 0.9298 - val_loss: 0.2466 - val_accuracy: 0.8750
# Epoch 124/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2200 - accuracy: 0.8991 - val_loss: 0.2436 - val_accuracy: 0.8500
# Epoch 125/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2038 - accuracy: 0.9342 - val_loss: 0.2467 - val_accuracy: 0.8500
# Epoch 126/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2043 - accuracy: 0.9079 - val_loss: 0.2507 - val_accuracy: 0.8500
# Epoch 127/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1891 - accuracy: 0.9298 - val_loss: 0.2492 - val_accuracy: 0.8500
# Epoch 128/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2583 - accuracy: 0.9035 - val_loss: 0.2472 - val_accuracy: 0.8500
# Epoch 129/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2126 - accuracy: 0.9079 - val_loss: 0.2488 - val_accuracy: 0.8750
# Epoch 130/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1820 - accuracy: 0.9518 - val_loss: 0.2698 - val_accuracy: 0.8750
# Epoch 131/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1885 - accuracy: 0.9298 - val_loss: 0.2818 - val_accuracy: 0.8750
# Epoch 132/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2105 - accuracy: 0.9386 - val_loss: 0.2704 - val_accuracy: 0.8750
# Epoch 133/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1917 - accuracy: 0.9035 - val_loss: 0.2580 - val_accuracy: 0.8750
# Epoch 134/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1935 - accuracy: 0.9254 - val_loss: 0.2540 - val_accuracy: 0.8750
# Epoch 135/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1927 - accuracy: 0.9298 - val_loss: 0.2424 - val_accuracy: 0.8750
# Epoch 136/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1766 - accuracy: 0.9430 - val_loss: 0.2347 - val_accuracy: 0.8750
# Epoch 137/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2753 - accuracy: 0.8684 - val_loss: 0.2379 - val_accuracy: 0.8750
# Epoch 138/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2123 - accuracy: 0.9167 - val_loss: 0.2335 - val_accuracy: 0.8750
# Epoch 139/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1942 - accuracy: 0.9342 - val_loss: 0.2349 - val_accuracy: 0.8750
# Epoch 140/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2156 - accuracy: 0.9035 - val_loss: 0.2426 - val_accuracy: 0.8750
# Epoch 141/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2002 - accuracy: 0.9342 - val_loss: 0.2334 - val_accuracy: 0.9000
# Epoch 142/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1860 - accuracy: 0.9079 - val_loss: 0.2355 - val_accuracy: 0.9000
# Epoch 143/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2208 - accuracy: 0.9167 - val_loss: 0.2322 - val_accuracy: 0.8750
# Epoch 144/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1842 - accuracy: 0.9386 - val_loss: 0.2284 - val_accuracy: 0.8750
# Epoch 145/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2062 - accuracy: 0.9298 - val_loss: 0.2261 - val_accuracy: 0.8750
# Epoch 146/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1613 - accuracy: 0.9342 - val_loss: 0.2279 - val_accuracy: 0.8750
# Epoch 147/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2319 - accuracy: 0.9211 - val_loss: 0.2266 - val_accuracy: 0.8500
# Epoch 148/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2352 - accuracy: 0.9035 - val_loss: 0.2266 - val_accuracy: 0.8750
# Epoch 149/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1988 - accuracy: 0.9167 - val_loss: 0.2196 - val_accuracy: 0.8750
# Epoch 150/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2067 - accuracy: 0.9211 - val_loss: 0.2171 - val_accuracy: 0.9250
# Epoch 151/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1839 - accuracy: 0.9298 - val_loss: 0.2169 - val_accuracy: 0.9000
# Epoch 152/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1896 - accuracy: 0.9254 - val_loss: 0.2209 - val_accuracy: 0.8750
# Epoch 153/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2234 - accuracy: 0.8991 - val_loss: 0.2331 - val_accuracy: 0.8750
# Epoch 154/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2078 - accuracy: 0.8991 - val_loss: 0.2175 - val_accuracy: 0.8750
# Epoch 155/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2018 - accuracy: 0.8991 - val_loss: 0.2142 - val_accuracy: 0.8750
# Epoch 156/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2142 - accuracy: 0.9123 - val_loss: 0.2130 - val_accuracy: 0.8750
# Epoch 157/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2045 - accuracy: 0.9342 - val_loss: 0.2041 - val_accuracy: 0.9000
# Epoch 158/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1534 - accuracy: 0.9518 - val_loss: 0.2011 - val_accuracy: 0.9000
# Epoch 159/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2313 - accuracy: 0.9079 - val_loss: 0.1994 - val_accuracy: 0.9250
# Epoch 160/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1901 - accuracy: 0.9298 - val_loss: 0.1981 - val_accuracy: 0.9250
# Epoch 161/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1655 - accuracy: 0.9430 - val_loss: 0.1992 - val_accuracy: 0.9250
# Epoch 162/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2045 - accuracy: 0.9167 - val_loss: 0.2014 - val_accuracy: 0.8750
# Epoch 163/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1424 - accuracy: 0.9430 - val_loss: 0.2019 - val_accuracy: 0.9000
# Epoch 164/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1655 - accuracy: 0.9386 - val_loss: 0.1986 - val_accuracy: 0.9250
# Epoch 165/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1953 - accuracy: 0.9211 - val_loss: 0.1988 - val_accuracy: 0.8750
# Epoch 166/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1984 - accuracy: 0.9079 - val_loss: 0.2000 - val_accuracy: 0.9250
# Epoch 167/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1931 - accuracy: 0.9298 - val_loss: 0.2020 - val_accuracy: 0.9250
# Epoch 168/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1827 - accuracy: 0.9167 - val_loss: 0.2057 - val_accuracy: 0.9000
# Epoch 169/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1646 - accuracy: 0.9386 - val_loss: 0.2063 - val_accuracy: 0.9000
# Epoch 170/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1944 - accuracy: 0.9298 - val_loss: 0.2095 - val_accuracy: 0.8500
# Epoch 171/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2056 - accuracy: 0.9211 - val_loss: 0.2129 - val_accuracy: 0.8750
# Epoch 172/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1769 - accuracy: 0.9386 - val_loss: 0.2165 - val_accuracy: 0.9000
# Epoch 173/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1566 - accuracy: 0.9386 - val_loss: 0.2178 - val_accuracy: 0.9000
# Epoch 174/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1822 - accuracy: 0.9386 - val_loss: 0.2193 - val_accuracy: 0.9000
# Epoch 175/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1629 - accuracy: 0.9342 - val_loss: 0.2175 - val_accuracy: 0.8750
# Epoch 176/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1797 - accuracy: 0.9342 - val_loss: 0.2189 - val_accuracy: 0.8750
# Epoch 177/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1961 - accuracy: 0.9342 - val_loss: 0.2196 - val_accuracy: 0.8750
# Epoch 178/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1769 - accuracy: 0.9430 - val_loss: 0.2296 - val_accuracy: 0.8750
# Epoch 179/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2150 - accuracy: 0.9079 - val_loss: 0.2358 - val_accuracy: 0.8750
# Epoch 180/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2235 - accuracy: 0.9079 - val_loss: 0.2258 - val_accuracy: 0.9000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, acc, label='training acc')
plt.plot(epochs, val_acc, label='validation acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy-%')
plt.legend()
plt.figure()

plt.plot(epochs, loss, label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy Loss')
plt.legend()

# %% [markdown]
# Brain model is performing succesfully. Now we can evaluate our model.

# %% [markdown]
# 6. EVALUATION OF MODEL

# %%
train_result = brain_model.evaluate(training_set)
val_result = brain_model.evaluate(test_set)
# Out:
# 8/8 [==============================] - 1s 34ms/step - loss: 0.1922 - accuracy: 0.9474
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1981 - accuracy: 0.9250

# %% [markdown]
# 7. FINAL RESULTS: 94.74% ACCURACY ON TRAINING SET
#                   92.50% ACCURACY ON TEST SET
